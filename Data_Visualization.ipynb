# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshreddy39/Ineuron-ML-DL-Solutions/blob/master/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this assignment students have to transform iris data into 3 dimensions and plot a 3d chart with transformed dimensions and colour each data point with specific class.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets

# %%
iris=datasets.load_iris()

# %%
x=iris.data
y=iris.target

# %%
pca=decomposition.PCA(n_components=3)
# The number of components = 3
X=pca.fit_transform(x)
print("Shape of pca_reduced.shape=",X.shape)
# Out:
# Shape of pca_reduced.shape= (150, 3)

# %%
fig = plt.figure(1, figsize=(7, 7))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
plt.cla()
y = np.choose(y, [1, 2, 0]).astype(float)
for name, label in [('Setosa', 0), ('Versicolour', 1), ('Virginica', 2)]:
    ax.text3D(X[y == label, 0].mean(),
              X[y == label, 1].mean() + 1.5,
              X[y == label, 2].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))
    
# Reorder the labels to have colors matching the cluster results

ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, edgecolor='k')
plt.show()
